# %% [markdown]
# Ссылка на colab
# https://colab.research.google.com/drive/1CTtzlNwkihbcXFhVVFkSt9hMEbQemoh7?usp=sharing

# %% [markdown]
# # Проект для «Викишоп» с BERT

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# Обучите модель классифицировать комментарии на позитивные и негативные. В вашем распоряжении набор данных с разметкой о токсичности правок.
#
# Постройте модель со значением метрики качества *F1* не меньше 0.75.
#
# **Инструкция по выполнению проекта**
#
# 1. Загрузите и подготовьте данные.
# 2. Обучите разные модели.
# 3. Сделайте выводы.
#
# Для выполнения проекта применять *BERT* необязательно, но вы можете попробовать.
#
# **Описание данных**
#
# Данные находятся в файле `toxic_comments.csv`. Столбец *text* в нём содержит текст комментария, а *toxic* — целевой признак.

# %% [markdown]
# ## Подготовка

# %%
# !pip install transformers

# %%
# !pip install catboost

# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import numpy as np
import torch
import transformers
import warnings
import lightgbm as lgb
import time

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

from tqdm import notebook
from tqdm import tqdm

from catboost import CatBoostClassifier, Pool

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Загрузка данных

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 df = pd.read_csv('/content/drive/MyDrive/01 DS/01 Yandex Practicum/toxic_comments/toxic_comments.csv')

# %% [markdown]
# ## Обучение

# %% [markdown]
# Загрузка предобученных модели и токенизатора.

# %%
model = transformers.AutoModel.from_pretrained('unitary/toxic-bert')
tokenizer = transformers.AutoTokenizer.from_pretrained('unitary/toxic-bert')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/811 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/174 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# Преобразуем текст

# %%
pre_tokenized = df['text'].apply(
  lambda x: tokenizer.encode(x, add_special_tokens=True))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (631 > 512). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Как видим из сообщения к pre_tokenized, имеем ограничение в 512 токенов в строке. Создадим такое ограничение.

# %% [markdown]
# Собираем датасет из токенизированных данных - столбец text, целевого признака и длин списков токенов.

# %%
df_temp = pd.DataFrame(pre_tokenized)
df_temp['toxic'] = df['toxic']
len_list = []
for i in df_temp['text']:
    len_list.append(len(i))
df_temp['len'] = len_list
df_temp
# Out:
#                                                      text  toxic  len
# 0       [101, 7526, 2339, 1996, 10086, 2015, 2081, 210...      0   68
# 1       [101, 1040, 1005, 22091, 2860, 999, 2002, 3503...      0   35
# 2       [101, 4931, 2158, 1010, 1045, 1005, 1049, 2428...      0   54
# 3       [101, 1000, 2062, 1045, 2064, 1005, 1056, 2191...      0  144
# 4       [101, 2017, 1010, 2909, 1010, 2024, 2026, 5394...      0   21
# ...                                                   ...    ...  ...
# 159287  [101, 1000, 1024, 1024, 1024, 1024, 1024, 1998...      0   68
# 159288  [101, 2017, 2323, 2022, 14984, 1997, 4426, 200...      0   27
# 159289  [101, 13183, 6290, 26114, 1010, 2045, 2015, 20...      0   19
# 159290  [101, 1998, 2009, 3504, 2066, 2009, 2001, 2941...      0   28
# 159291  [101, 1000, 1998, 1012, 1012, 1012, 1045, 2428...      0   51
#
# [159292 rows x 3 columns]

# %% [markdown]
# Удаляем строки с превышающими лимит токенами. таких строк порядка 1.8%

# %%
df_temp = df_temp.loc[df_temp['len'] < 513].drop(['len'], axis=1)

# %% [markdown]
# Собираем данные по индексу: слева - тексты из исходного датасета, справа - целевой признак из нового, отфильтрованного датасета. Так как join имеет значение inner, то остаются только те строки, в которых совпадает индекс, то есть прошедшие фильтрацию.

# %%
df_left = df['text']
df_right = df_temp['toxic']
result = pd.concat([df_left, df_right], axis=1, join="inner")
result
# Out:
#                                                      text  toxic
# 0       Explanation\nWhy the edits made under my usern...      0
# 1       D'aww! He matches this background colour I'm s...      0
# 2       Hey man, I'm really not trying to edit war. It...      0
# 3       "\nMore\nI can't make any real suggestions on ...      0
# 4       You, sir, are my hero. Any chance you remember...      0
# ...                                                   ...    ...
# 159287  ":::::And for the second time of asking, when ...      0
# 159288  You should be ashamed of yourself \n\nThat is ...      0
# 159289  Spitzer \n\nUmm, theres no actual article for ...      0
# 159290  And it looks like it was actually you who put ...      0
# 159291  "\nAnd ... I really don't think you understand...      0
#
# [155789 rows x 2 columns]

# %% [markdown]
# В случае преобразования в эмбенддинги внутри ноутбука, код ниже - указывает количество семплов для будущего датасета, где q_sample = len(result) - это полный датасет.
#
# Ниже приведен пример расчета для очень маленькой выборки - взяли 256 строк, чтобы показать работоспособность кода.
#
# Полный преобразованный датасет будет использоваться уже на этапе разделения признаков и целевого признака.

# %%
q_sample = 4096 # нужное число для датасета, вплоть до q_sample = len(result)
result = result.sample(q_sample).reset_index(drop=True)

# %% [markdown]
# ### Преобразуем текст предобработанных данных

# %% [markdown]
# Токенизируем отфильтрованную выборку.

# %%
tokenized = result['text'].apply(
  lambda x: tokenizer.encode(x, add_special_tokens=True))

# %% [markdown]
# Предупреждения больше нет. Максимальная длина токена max_len равна ограничению - 512. Вынесли это значения в константы.
#
# При исполнении преобразования внутри ноутбука, max_len расчитывается ниже. Так как мы случайным образом отберем какое-то количество строк, может случиться, что строки будут короче константной max_len = 512, это нужно учитывать

# %%
max_len = 0
for i in tokenized.values:
    if len(i) > max_len:
        max_len = len(i)
max_len
# Out:
# 512

# %% [markdown]
# ### Преобразование векторов

# %% [markdown]
# Паддингом добавляем к каждому вектору нули в конец, так, чтобы длина каждого вектора была равна длине max_len.
#
# Маска тоже применяется к каждому вектору - значению, отличному от нуля, присваивается 1, нули остаются нулями.

# %%
padded = np.array([i + [0]*(max_len - len(i)) for i in tokenized.values])
attention_mask = np.where(padded != 0, 1, 0)

# %% [markdown]
# ### Преобразование в эмбеддинги

# %%
# %%time
from tqdm import notebook
batch_size = 64 # для примера возьмем такой батч, где будет всего две строки датасета
embeddings = []
for i in notebook.tqdm(range(padded.shape[0] // batch_size)):
        batch = torch.LongTensor(padded[batch_size*i:batch_size*(i+1)]).cuda() # закидываем тензор на GPU
        attention_mask_batch = torch.LongTensor(attention_mask[batch_size*i:batch_size*(i+1)]).cuda()

        with torch.no_grad():
            model.cuda()
            batch_embeddings = model(batch, attention_mask=attention_mask_batch)

        embeddings.append(batch_embeddings[0][:,0,:].cpu().numpy()) # перевод обратно на проц, чтобы в нумпай кинуть
        del batch
        del attention_mask_batch
        del batch_embeddings

df_ed = pd.DataFrame(np.concatenate(embeddings)) # соберём все эмбеддинги в матрицу признаков вызовом функции concatenate()
df_ed['toxic'] = result['toxic'] # добавляем целевой признак
df_ed
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
# CPU times: user 2min 9s, sys: 492 ms, total: 2min 9s
# Wall time: 2min 16s
#              0         1         2         3         4         5         6  \
# 0    -0.586298 -0.939466  0.659756 -0.421844  0.985815  0.292342 -0.134406
# 1    -0.831884 -0.865431  0.473457 -0.384296  1.035798  0.240806 -0.190848
# 2    -0.328855  0.504372  0.781910  0.212954 -0.548644  0.684209  1.324862
# 3    -0.598833 -0.917849  0.679589 -0.345724  0.975384  0.124146 -0.138577
# 4    -0.510330 -0.780005  0.560046 -0.423635  0.970720  0.230853 -0.078740
# ...        ...       ...       ...       ...       ...       ...       ...
# 4091 -0.671228 -0.864717  0.382037 -0.555415  0.911503  0.255179 -0.178668
# 4092 -0.605584 -1.078846  0.511130 -0.455643  0.991373  0.380742 -0.094920
# 4093 -0.716489 -0.938596  0.477114 -0.446761  1.001965  0.252554 -0.185593
# 4094 -0.575461 -0.986935  0.647507 -0.456455  0.965278  0.291799 -0.067759
# 4095 -0.507828 -0.976000  0.527018 -0.460119  1.017524  0.226628 -0.159927
#
#              7         8         9  ...       759       760       761  \
# 0     0.034419 -0.389288 -0.620233  ... -1.336425  0.248437 -0.657485
# 1     0.060595 -0.324949 -0.617155  ... -1.266620  0.152800 -0.738499
# 2     0.645755 -0.348915  0.475758  ...  0.925567 -0.536889 -0.557106
# 3     0.141820 -0.332999 -0.661736  ... -1.258238  0.195049 -0.706208
# 4     0.020176 -0.381334 -0.636837  ... -1.205820  0.254241 -0.646155
# ...        ...       ...       ...  ...       ...       ...       ...
# 4091  0.013631 -0.461592 -0.662355  ... -1.216205  0.399859 -0.745357
# 4092  0.014984 -0.187413 -0.625181  ... -1.319477  0.124943 -0.653278
# 4093 -0.004704 -0.453163 -0.710956  ... -1.271600  0.238129 -0.756693
# 4094 -0.056234 -0.373591 -0.715119  ... -1.230942  0.190661 -0.708521
# 4095  0.037601 -0.439829 -0.577726  ... -1.121476  0.238235 -0.678829
#
#            762       763       764       765       766       767  toxic
# 0     0.085443  0.865121 -0.376805 -0.737543  0.387663  0.142325      0
# 1     0.103554  0.898390 -0.574140 -0.758753  0.477778  0.122623      0
# 2    -0.830609 -0.632906 -0.130944 -0.300695  0.176920  0.300887      1
# 3     0.161176  0.873706 -0.512138 -0.736954  0.407379  0.071533      0
# 4     0.173264  0.896006 -0.421585 -0.733386  0.393443  0.159418      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 4091  0.130172  0.951795 -0.439261 -0.724997  0.461565  0.005745      0
# 4092  0.120543  0.794026 -0.340826 -0.752100  0.574000  0.120635      0
# 4093  0.170392  0.902686 -0.515896 -0.725224  0.328117 -0.012677      0
# 4094  0.165780  0.919065 -0.389543 -0.757118  0.447476  0.037201      0
# 4095  0.144238  0.700947 -0.533691 -0.785179  0.560491  0.008196      0
#
# [4096 rows x 769 columns]

# %%
df_ed = df_ed.astype('float32') #меняем тип - чтобы при работе с данными требовалось меньше памяти
df_ed['toxic'] = df_ed['toxic'].astype('int16')

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split( #создаем 4 датасета, два признаков (тест+валидация) и два целевых,
    df_ed.drop(columns='toxic'), #для датасетов признаков удаляем целевой
    df_ed['toxic'], #для целевого оставляем только целевой
    test_size=0.2, #с соотношением
    random_state=42, #с заданной опорой для рандома
    stratify= df_ed['toxic']) #с заданной стратификацией по целевому признаку

# %%
X_train, X_val, y_train, y_val = train_test_split( #создаем 4 датасета, два признаков (тест+валидация) и два целевых,
    X_train_val,
    y_train_val,
    test_size=0.2, #с соотношением
    random_state=42, #с заданной опорой для рандома
    stratify=y_train_val) #с заданной стратификацией по целевому признаку

# %% [markdown]
# ### CatBoostClassifier

# %%
start_time = time.time()

cbr = CatBoostClassifier(verbose=100,
                         task_type="GPU")

parameters = {
    'depth': [5,10,20,50],
    'learning_rate': [0.01, 0.02, 0.03],
    'iterations': [300, 500, 1000]
 }

rand_cbc = RandomizedSearchCV(cbr,
                              n_iter=20,
                              param_distributions= parameters,
                              scoring='f1',
                              n_jobs= -2,
                              cv=3,
                              random_state=42)

rand_cbc.fit(X_train, y_train.values)

best_rand_cbc = rand_cbc.best_score_

time_cbc = time.time() - start_time

print("Лучшие параметры для модели логистической регрессии с "\
    "использованием кросс-валидации:", rand_cbc.best_params_)
print("Наибольшее значение метрики F1 для модели логистической регрессии "\
    "при лучших гиперпараметрах с использованием кросс-валидации:", rand_cbc)
print(f'Время выполнения - {round(time_cbc,2)}  сек.')
# Out:
# 0:	learn: 0.5605250	total: 41.9ms	remaining: 2.05s
# 49:	learn: 0.0165284	total: 1.82s	remaining: 0us
# 0:	learn: 0.5674859	total: 28.6ms	remaining: 1.4s
# 49:	learn: 0.0184810	total: 1.48s	remaining: 0us
# 0:	learn: 0.5674322	total: 12.7ms	remaining: 622ms
# 49:	learn: 0.0167282	total: 1.17s	remaining: 0us
# 0:	learn: 0.6650552	total: 218ms	remaining: 1.96s
# 9:	learn: 0.4585873	total: 2.04s	remaining: 0us
# 0:	learn: 0.6668371	total: 115ms	remaining: 1.03s
# 9:	learn: 0.4647902	total: 1.35s	remaining: 0us
# 0:	learn: 0.6643910	total: 112ms	remaining: 1.01s
# 9:	learn: 0.4530894	total: 1.08s	remaining: 0us
# 0:	learn: 0.6648672	total: 17.3ms	remaining: 156ms
# 9:	learn: 0.4564276	total: 283ms	remaining: 0us
# 0:	learn: 0.6664840	total: 30.3ms	remaining: 273ms
# 9:	learn: 0.4681792	total: 301ms	remaining: 0us
# 0:	learn: 0.6664413	total: 17.5ms	remaining: 158ms
# 9:	learn: 0.4568692	total: 146ms	remaining: 0us
# 0:	learn: 0.5614388	total: 79.2ms	remaining: 23.7s
# 100:	learn: 0.0044513	total: 13.2s	remaining: 26s
# 200:	learn: 0.0017676	total: 20.3s	remaining: 10s
# 299:	learn: 0.0010588	total: 31.6s	remaining: 0us
# 0:	learn: 0.5691436	total: 69.6ms	remaining: 20.8s
# 100:	learn: 0.0049234	total: 12.1s	remaining: 23.8s
# 200:	learn: 0.0018797	total: 22.9s	remaining: 11.3s
# 299:	learn: 0.0011029	total: 37.9s	remaining: 0us
# 0:	learn: 0.5586863	total: 111ms	remaining: 33.2s
# 100:	learn: 0.0041619	total: 14s	remaining: 27.6s
# 200:	learn: 0.0017161	total: 29.9s	remaining: 14.7s
# 299:	learn: 0.0010640	total: 40.5s	remaining: 0us
# 0:	learn: 0.5605250	total: 44.3ms	remaining: 13.2s
# 100:	learn: 0.0090023	total: 4.15s	remaining: 8.18s
# 200:	learn: 0.0033867	total: 6.53s	remaining: 3.21s
# 299:	learn: 0.0018498	total: 9.22s	remaining: 0us
# 0:	learn: 0.5674859	total: 18.3ms	remaining: 5.48s
# 100:	learn: 0.0097869	total: 1.94s	remaining: 3.83s
# 200:	learn: 0.0039547	total: 2.78s	remaining: 1.37s
# 299:	learn: 0.0021711	total: 5.03s	remaining: 0us
# 0:	learn: 0.5674322	total: 29.5ms	remaining: 8.82s
# 100:	learn: 0.0082193	total: 2.87s	remaining: 5.66s
# 200:	learn: 0.0034096	total: 3.76s	remaining: 1.85s
# 299:	learn: 0.0019149	total: 4.58s	remaining: 0us
# 0:	learn: 0.5654106	total: 563ms	remaining: 9m 22s
# 100:	learn: 0.0045342	total: 1m 3s	remaining: 9m 25s
# 200:	learn: 0.0017073	total: 2m 3s	remaining: 8m 10s
# 300:	learn: 0.0010838	total: 3m 4s	remaining: 7m 8s
# 400:	learn: 0.0007763	total: 4m 3s	remaining: 6m 3s
# 500:	learn: 0.0006176	total: 5m 3s	remaining: 5m 2s
# 600:	learn: 0.0004997	total: 6m 4s	remaining: 4m 1s
# 700:	learn: 0.0004221	total: 7m 3s	remaining: 3m
# 800:	learn: 0.0003669	total: 8m 3s	remaining: 2m
# 900:	learn: 0.0003240	total: 9m 3s	remaining: 59.7s
# 999:	learn: 0.0002885	total: 10m 2s	remaining: 0us
# 0:	learn: 0.5678861	total: 589ms	remaining: 9m 48s
# 100:	learn: 0.0060047	total: 1m	remaining: 9m 1s
# 200:	learn: 0.0024433	total: 1m 59s	remaining: 7m 54s
# 300:	learn: 0.0014186	total: 2m 58s	remaining: 6m 54s
# 400:	learn: 0.0010503	total: 3m 57s	remaining: 5m 54s
# 500:	learn: 0.0008100	total: 4m 55s	remaining: 4m 54s
# 600:	learn: 0.0006841	total: 5m 54s	remaining: 3m 55s
# 700:	learn: 0.0005960	total: 6m 54s	remaining: 2m 57s
# 800:	learn: 0.0005242	total: 7m 53s	remaining: 1m 57s
# 900:	learn: 0.0004685	total: 8m 54s	remaining: 58.8s
# 999:	learn: 0.0004279	total: 10m	remaining: 0us
# 0:	learn: 0.5725247	total: 715ms	remaining: 11m 54s
# 100:	learn: 0.0050500	total: 1m 2s	remaining: 9m 18s
# 200:	learn: 0.0020888	total: 2m 1s	remaining: 8m 2s
# 300:	learn: 0.0014309	total: 2m 59s	remaining: 6m 57s
# 400:	learn: 0.0011325	total: 3m 59s	remaining: 5m 57s
# 500:	learn: 0.0009582	total: 5m 5s	remaining: 5m 4s
# 600:	learn: 0.0008267	total: 6m 12s	remaining: 4m 7s
# 700:	learn: 0.0007196	total: 7m 19s	remaining: 3m 7s
# 800:	learn: 0.0006601	total: 8m 26s	remaining: 2m 5s
# 900:	learn: 0.0005990	total: 9m 32s	remaining: 1m 2s
# 999:	learn: 0.0005386	total: 10m 36s	remaining: 0us
# 0:	learn: 0.6666510	total: 35.7ms	remaining: 17.8s
# 100:	learn: 0.0448646	total: 3.42s	remaining: 13.5s
# 200:	learn: 0.0207649	total: 7.97s	remaining: 11.9s
# 300:	learn: 0.0150013	total: 14.8s	remaining: 9.78s
# 400:	learn: 0.0117462	total: 27.4s	remaining: 6.76s
# 499:	learn: 0.0097047	total: 34.3s	remaining: 0us
# 0:	learn: 0.6655953	total: 34.4ms	remaining: 17.2s
# 100:	learn: 0.0494304	total: 3.66s	remaining: 14.5s
# 200:	learn: 0.0237582	total: 9.41s	remaining: 14s
# 300:	learn: 0.0177631	total: 12.8s	remaining: 8.49s
# 400:	learn: 0.0150525	total: 16.1s	remaining: 3.96s
# 499:	learn: 0.0132400	total: 19.2s	remaining: 0us
# 0:	learn: 0.6674366	total: 86.1ms	remaining: 43s
# 100:	learn: 0.0450074	total: 6.17s	remaining: 24.4s
# 200:	learn: 0.0210257	total: 9.43s	remaining: 14s
# 300:	learn: 0.0142302	total: 12.7s	remaining: 8.39s
# 400:	learn: 0.0108648	total: 17.1s	remaining: 4.21s
# 499:	learn: 0.0087856	total: 22.2s	remaining: 0us
# 0:	learn: 0.5654106	total: 556ms	remaining: 4m 37s
# 100:	learn: 0.0045342	total: 58.7s	remaining: 3m 52s
# 200:	learn: 0.0017073	total: 1m 57s	remaining: 2m 54s
# 300:	learn: 0.0010838	total: 2m 58s	remaining: 1m 57s
# 400:	learn: 0.0007763	total: 3m 56s	remaining: 58.4s
# 499:	learn: 0.0006182	total: 4m 55s	remaining: 0us
# 0:	learn: 0.5678861	total: 554ms	remaining: 4m 36s
# 100:	learn: 0.0060047	total: 58.1s	remaining: 3m 49s
# 200:	learn: 0.0024433	total: 1m 56s	remaining: 2m 52s
# 300:	learn: 0.0014186	total: 2m 54s	remaining: 1m 55s
# 400:	learn: 0.0010503	total: 3m 57s	remaining: 58.6s
# 499:	learn: 0.0008126	total: 5m 2s	remaining: 0us
# 0:	learn: 0.5725247	total: 556ms	remaining: 4m 37s
# 100:	learn: 0.0050500	total: 59.5s	remaining: 3m 54s
# 200:	learn: 0.0020888	total: 1m 58s	remaining: 2m 56s
# 300:	learn: 0.0014309	total: 2m 57s	remaining: 1m 57s
# 400:	learn: 0.0011325	total: 3m 55s	remaining: 58.2s
# 499:	learn: 0.0009585	total: 4m 53s	remaining: 0us
# 0:	learn: 0.6648672	total: 29.1ms	remaining: 8.69s
# 100:	learn: 0.0413962	total: 2.83s	remaining: 5.58s
# 200:	learn: 0.0197190	total: 3.64s	remaining: 1.79s
# 299:	learn: 0.0141536	total: 4.44s	remaining: 0us
# 0:	learn: 0.6664840	total: 8.81ms	remaining: 2.63s
# 100:	learn: 0.0454611	total: 829ms	remaining: 1.63s
# 200:	learn: 0.0220637	total: 1.63s	remaining: 801ms
# 299:	learn: 0.0158068	total: 2.42s	remaining: 0us
# 0:	learn: 0.6664413	total: 8.82ms	remaining: 2.64s
# 100:	learn: 0.0428408	total: 835ms	remaining: 1.65s
# 200:	learn: 0.0207940	total: 1.64s	remaining: 807ms
# 299:	learn: 0.0146964	total: 2.44s	remaining: 0us
# 0:	learn: 0.4493506	total: 29ms	remaining: 1.42s
# 49:	learn: 0.0093120	total: 1.37s	remaining: 0us
# 0:	learn: 0.4605939	total: 24.3ms	remaining: 1.19s
# 49:	learn: 0.0101029	total: 1.63s	remaining: 0us
# 0:	learn: 0.4608550	total: 30.4ms	remaining: 1.49s
# 49:	learn: 0.0082852	total: 1.81s	remaining: 0us
# 0:	learn: 0.5614388	total: 82.2ms	remaining: 4.03s
# 49:	learn: 0.0109625	total: 3.49s	remaining: 0us
# 0:	learn: 0.5691436	total: 59ms	remaining: 2.89s
# 49:	learn: 0.0118126	total: 3.03s	remaining: 0us
# 0:	learn: 0.5586863	total: 58.6ms	remaining: 2.87s
# 49:	learn: 0.0105300	total: 3.08s	remaining: 0us
# 0:	learn: 0.6659779	total: 622ms	remaining: 10m 21s
# 100:	learn: 0.0425836	total: 52.4s	remaining: 7m 46s
# 200:	learn: 0.0160018	total: 1m 50s	remaining: 7m 19s
# 300:	learn: 0.0093518	total: 2m 49s	remaining: 6m 32s
# 400:	learn: 0.0062134	total: 3m 47s	remaining: 5m 40s
# 500:	learn: 0.0044587	total: 4m 46s	remaining: 4m 45s
# 600:	learn: 0.0034159	total: 5m 45s	remaining: 3m 49s
# 700:	learn: 0.0027427	total: 6m 44s	remaining: 2m 52s
# 800:	learn: 0.0023112	total: 7m 43s	remaining: 1m 55s
# 900:	learn: 0.0019850	total: 8m 43s	remaining: 57.5s
# 999:	learn: 0.0017325	total: 9m 42s	remaining: 0us
# 0:	learn: 0.6664924	total: 562ms	remaining: 9m 21s
# 100:	learn: 0.0459645	total: 53.2s	remaining: 7m 53s
# 200:	learn: 0.0187108	total: 1m 51s	remaining: 7m 23s
# 300:	learn: 0.0113781	total: 2m 49s	remaining: 6m 33s
# 400:	learn: 0.0079819	total: 3m 48s	remaining: 5m 41s
# 500:	learn: 0.0060095	total: 4m 46s	remaining: 4m 45s
# 600:	learn: 0.0048230	total: 5m 46s	remaining: 3m 49s
# 700:	learn: 0.0040489	total: 6m 44s	remaining: 2m 52s
# 800:	learn: 0.0034892	total: 7m 43s	remaining: 1m 55s
# 900:	learn: 0.0030355	total: 8m 42s	remaining: 57.4s
# 999:	learn: 0.0026446	total: 9m 39s	remaining: 0us
# 0:	learn: 0.6676074	total: 578ms	remaining: 9m 37s
# 100:	learn: 0.0443970	total: 51.6s	remaining: 7m 39s
# 200:	learn: 0.0168463	total: 1m 50s	remaining: 7m 17s
# 300:	learn: 0.0094806	total: 2m 48s	remaining: 6m 31s
# 400:	learn: 0.0062349	total: 3m 47s	remaining: 5m 39s
# 500:	learn: 0.0045710	total: 4m 46s	remaining: 4m 45s
# 600:	learn: 0.0035391	total: 5m 44s	remaining: 3m 48s
# 700:	learn: 0.0029448	total: 6m 43s	remaining: 2m 51s
# 800:	learn: 0.0025147	total: 7m 42s	remaining: 1m 54s
# 900:	learn: 0.0021982	total: 8m 40s	remaining: 57.2s
# 999:	learn: 0.0019526	total: 9m 38s	remaining: 0us
# 0:	learn: 0.6671445	total: 454ms	remaining: 7m 34s
# 100:	learn: 0.0447697	total: 52.1s	remaining: 7m 43s
# 200:	learn: 0.0186263	total: 1m 51s	remaining: 7m 21s
# 300:	learn: 0.0117126	total: 2m 50s	remaining: 6m 35s
# 400:	learn: 0.0082973	total: 3m 49s	remaining: 5m 43s
# 500:	learn: 0.0063283	total: 4m 47s	remaining: 4m 46s
# 600:	learn: 0.0051458	total: 5m 46s	remaining: 3m 49s
# 700:	learn: 0.0042666	total: 6m 45s	remaining: 2m 52s
# 800:	learn: 0.0036366	total: 7m 44s	remaining: 1m 55s
# 900:	learn: 0.0031611	total: 8m 43s	remaining: 57.5s
# 999:	learn: 0.0027884	total: 9m 41s	remaining: 0us
# Лучшие параметры для модели логистической регрессии с использованием кросс-валидации: {'learning_rate': 0.01, 'iterations': 1000, 'depth': 10}
# Наибольшее значение метрики F1 для модели логистической регрессии при лучших гиперпараметрах с использованием кросс-валидации: 0.9345644117831794
# Время выполнения - 5333.42  сек.

# %%
catbost_f1 = round(f1_score(y_val, rand_cbc.best_estimator_.predict(X_val)), 5)
catbost_f1
# Out:
# 0.94737

# %%
print(f'Значение метрики f1 = {catbost_f1}')
# Out:
# Значение метрики f1 = 0.9474

# %% [markdown]
# ### LogisticRegression

# %%
start_time = time.time()

log_reg = LogisticRegression(solver='liblinear',
                             random_state=42,
                             class_weight= 'balanced') #максимальное количество итераций 1000

parameters = {'max_iter': range (100, 1000, 100),
              'C': np.arange(0.1, 1.0, 0.1)} #перебор гиперпараметров

rand_log_reg = RandomizedSearchCV(log_reg,
                                  n_iter=20,
                                  param_distributions= parameters,
                                  scoring='f1',
                                  n_jobs= -2,
                                  cv=3,
                                  random_state=42)

rand_log_reg.fit(X_train, y_train.values)

best_log_reg = rand_log_reg.best_score_

time_lr = time.time() - start_time

print("Лучшие параметры для модели логистической регрессии с "\
    "использованием кросс-валидации:", rand_log_reg.best_params_)
print("Наибольшее значение метрики F1 для модели логистической регрессии "\
    "при лучших гиперпараметрах с использованием кросс-валидации:", best_log_reg)
print(f'Время выполнения - {round(time_lr,2)}  сек.')
# Out:
# Лучшие параметры для модели логистической регрессии с использованием кросс-валидации: {'max_iter': 200, 'C': 0.9}
# Наибольшее значение метрики F1 для модели логистической регрессии при лучших гиперпараметрах с использованием кросс-валидации: 0.9195867492898723
# Время выполнения - 20.96  сек.

# %%
log_reg_f1 = round(f1_score(y_val, rand_log_reg.best_estimator_.predict(X_val)), 5)
log_reg_f1
# Out:
# 0.94964

# %% [markdown]
# ### RandomForestClassifier

# %%
start_time = time.time()

forest = RandomForestClassifier(class_weight= 'balanced',
                                random_state=42) #модель случайного леса

parameters = {'n_estimators': range (1, 300),
              'max_depth': range (1, 50)} #перебор гиперпараметров
#применение метода гридсёрч со встроенной кросс-валидацией к модели леса с перебором указанных параметров

randomized_forest = RandomizedSearchCV(forest,
                                       n_iter=20,
                                       param_distributions=parameters,
                                       scoring='f1',
                                       n_jobs= -2,
                                       cv=5,
                                       random_state=42)
#обучение модели
randomized_forest.fit(X_train, y_train.values)

#лучшее значение после перебора параметров
best_forest = randomized_forest.best_score_

time_forest = time.time() - start_time

print("Лучшие параметры для модели случайного леса с "\
    "использованием кросс-валидации:", randomized_forest.best_params_)
print("Наибольшее значение метрики F1 для модели случайного леса "\
    "при лучших гиперпараметрах с использованием кросс-валидации:", best_forest)
print(f'Время выполнения - {round(time_forest,2)}')
# Out:
# Лучшие параметры для модели случайного леса с использованием кросс-валидации: {'n_estimators': 222, 'max_depth': 38}
# Наибольшее значение метрики F1 для модели случайного леса при лучших гиперпараметрах с использованием кросс-валидации: 0.9303050833166069
# Время выполнения - 289.38

# %%
fandfor_f1 = round(f1_score(y_val, randomized_forest.best_estimator_.predict(X_val)), 5)
fandfor_f1
# Out:
# 0.94737

# %%
models = ['CatBoostClassifier', 'LogisticRegression', 'RandomForestClassifier']
F1 = [catbost_f1, log_reg_f1, fandfor_f1]
total_time = [round(time_cbc,2), round(time_lr,2), round(time_forest,2)]

result = pd.DataFrame({
    'Модель': models,
    'F1': F1,
    'Время выполнения': total_time
})
result.sort_values(by='F1')
# Out:
#                    Модель       F1  Время выполнения
# 0      CatBoostClassifier  0.94737           5333.42
# 2  RandomForestClassifier  0.94737            289.38
# 1      LogisticRegression  0.94964             20.96

# %% [markdown]
# ### Тест лучщей модели

# %%
print(f'f1 модели catbost - {round(f1_score(y_test, rand_cbc.best_estimator_.predict(X_test)), 2)}')
# Out:
# f1 модели catbost - 0.93

# %% [markdown]
# ## Выводы

# %% [markdown]
# Была использована модель BERT для создания признаков и обучена на этих лучшая модель молель CatBoost. Значение метрики F1 на тестовой выборке 0.93
